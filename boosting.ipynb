# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\kirat\appdata\roaming\python\python313\site-packages (from mlxtend) (1.16.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\kirat\appdata\roaming\python\python313\site-packages (from mlxtend) (2.2.0)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\kirat\appdata\roaming\python\python313\site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\kirat\appdata\roaming\python\python313\site-packages (from mlxtend) (1.7.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\kirat\appdata\roaming\python\python313\site-packages (from mlxtend) (3.9.3)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\kirat\appdata\roaming\python\python313\site-packages (from mlxtend) (1.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kirat\appdata\roaming\python\python313\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\kirat\appdata\roaming\python\python313\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kirat\appdata\roaming\python\python313\site-packages (from matplotlib>=3.0.0->mlxtend) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kirat\appdata\roaming\python\python313\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\kirat\appdata\roaming\python\python313\site-packages (from matplotlib>=3.0.0->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\kirat\appdata\roaming\python\python313\site-packages (from matplotlib>=3.0.0->mlxtend) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kirat\appdata\roaming\python\python313\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kirat\appdata\roaming\python\python313\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kirat\appdata\roaming\python\python313\site-packages (from pandas>=0.24.2->mlxtend) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kirat\appdata\roaming\python\python313\site-packages (from pandas>=0.24.2->mlxtend) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\kirat\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kirat\appdata\roaming\python\python313\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.4 MB 41.0 kB/s eta 0:00:21
#    --------------- ------------------------ 0.5/1.4 MB 41.0 kB/s eta 0:00:21
#    --------------- ------------------------ 0.5/1.4 MB 41.0 kB/s eta 0:00:21
#    --------------- ------------------------ 0.5/1.4 MB 41.0 kB/s eta 0:00:21
#    --------------- ------------------------ 0.5/1.4 MB 41.0 kB/s eta 0:00:21
#    --------------- ------------------------ 0.5/1.4 MB 41.0 kB/s eta 0:00:21
#    --------------- ------------------------ 0.5/1.4 MB 41.0 kB/s eta 0:00:21
#    --------------- ------------------------ 0.5/1.4 MB 41.0 kB/s eta 0:00:21
#    --------------- ------------------------ 0.5/1.4 MB 41.0 kB/s eta 0:00:21
#    --------------- ------------------------ 0.5/1.4 MB 41.0 kB/s eta 0:00:21
#    --------------- ------------------------ 0.5/1.4 MB 41.0 kB/s eta 0:00:21
#    --------------- ------------------------ 0.5/1.4 MB 41.0 kB/s eta 0:00:21
#    --------------- ------------------------ 0.5/1.4 MB 41.0 kB/s eta 0:00:21
#    --------------- ------------------------ 0.5/1.4 MB 41.0 kB/s eta 0:00:21
#    --------------- ------------------------ 0.5/1.4 MB 41.0 kB/s eta 0:00:21
#    --------------- ------------------------ 0.5/1.4 MB 41.0 kB/s eta 0:00:21
#    --------------- ------------------------ 0.5/1.4 MB 41.0 kB/s eta 0:00:21
#    ----------------------- ---------------- 0.8/1.4 MB 53.3 kB/s eta 0:00:11
#    ----------------------- ---------------- 0.8/1.4 MB 53.3 kB/s eta 0:00:11
#    ----------------------- ---------------- 0.8/1.4 MB 53.3 kB/s eta 0:00:11
#    ----------------------- ---------------- 0.8/1.4 MB 53.3 kB/s eta 0:00:11
#    ----------------------- ---------------- 0.8/1.4 MB 53.3 kB/s eta 0:00:11
#    ----------------------- ---------------- 0.8/1.4 MB 53.3 kB/s eta 0:00:11
#    ----------------------- ---------------- 0.8/1.4 MB 53.3 kB/s eta 0:00:11
#    ----------------------- ---------------- 0.8/1.4 MB 53.3 kB/s eta 0:00:11
#    ----------------------- ---------------- 0.8/1.4 MB 53.3 kB/s eta 0:00:11
#    ----------------------- ---------------- 0.8/1.4 MB 53.3 kB/s eta 0:00:11
#    ----------------------- ---------------- 0.8/1.4 MB 53.3 kB/s eta 0:00:11
#    ----------------------- ---------------- 0.8/1.4 MB 53.3 kB/s eta 0:00:11
#    ----------------------- ---------------- 0.8/1.4 MB 53.3 kB/s eta 0:00:11
#    ----------------------- ---------------- 0.8/1.4 MB 53.3 kB/s eta 0:00:11
#    ----------------------- ---------------- 0.8/1.4 MB 53.3 kB/s eta 0:00:11
#    ------------------------------- -------- 1.0/1.4 MB 60.9 kB/s eta 0:00:05
#    ------------------------------- -------- 1.0/1.4 MB 60.9 kB/s eta 0:00:05
#    ------------------------------- -------- 1.0/1.4 MB 60.9 kB/s eta 0:00:05
#    ------------------------------- -------- 1.0/1.4 MB 60.9 kB/s eta 0:00:05
#    ------------------------------- -------- 1.0/1.4 MB 60.9 kB/s eta 0:00:05
#    ------------------------------- -------- 1.0/1.4 MB 60.9 kB/s eta 0:00:05
#    ------------------------------- -------- 1.0/1.4 MB 60.9 kB/s eta 0:00:05
#    ------------------------------- -------- 1.0/1.4 MB 60.9 kB/s eta 0:00:05
#    ------------------------------- -------- 1.0/1.4 MB 60.9 kB/s eta 0:00:05
#    ------------------------------- -------- 1.0/1.4 MB 60.9 kB/s eta 0:00:05
#    ------------------------------- -------- 1.0/1.4 MB 60.9 kB/s eta 0:00:05
#    ------------------------------- -------- 1.0/1.4 MB 60.9 kB/s eta 0:00:05
#    ------------------------------- -------- 1.0/1.4 MB 60.9 kB/s eta 0:00:05
#    ------------------------------- -------- 1.0/1.4 MB 60.9 kB/s eta 0:00:05
#    ------------------------------- -------- 1.0/1.4 MB 60.9 kB/s eta 0:00:05
#    ------------------------------- -------- 1.0/1.4 MB 60.9 kB/s eta 0:00:05
#    ------------------------------- -------- 1.0/1.4 MB 60.9 kB/s eta 0:00:05
#    ------------------------------- -------- 1.0/1.4 MB 60.9 kB/s eta 0:00:05
#    ------------------------------- -------- 1.0/1.4 MB 60.9 kB/s eta 0:00:05
#    ------------------------------- -------- 1.0/1.4 MB 60.9 kB/s eta 0:00:05
#    ------------------------------- -------- 1.0/1.4 MB 60.9 kB/s eta 0:00:05
#    ------------------------------- -------- 1.0/1.4 MB 60.9 kB/s eta 0:00:05
#    ------------------------------- -------- 1.0/1.4 MB 60.9 kB/s eta 0:00:05
#    -------------------------------------- - 1.3/1.4 MB 59.2 kB/s eta 0:00:01
#    -------------------------------------- - 1.3/1.4 MB 59.2 kB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 60.1 kB/s  0:00:22
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
from mlxtend.plotting import plot_decision_regions

# %%
df=pd.DataFrame()

# %%
df['X1']=[1,2,3,4,5,6,6,7,9,9]
df['X2']=[5,3,6,8,1,9,5,8,9,2]
df['label']=[1,1,0,1,0,1,0,1,0,0]

# %%
df
# Out:
#    X1  X2  label
# 0   1   5      1
# 1   2   3      1
# 2   3   6      0
# 3   4   8      1
# 4   5   1      0
# 5   6   9      1
# 6   6   5      0
# 7   7   8      1
# 8   9   9      0
# 9   9   2      0

# %%
import seaborn as sns
sns.scatterplot(x=df['X1'],y=df['X2'],hue=df['label'])
# Out:
# <Axes: xlabel='X1', ylabel='X2'>

# %%
df['weights']=1/df.shape[0]

# %%
df
# Out:
#    X1  X2  label  weights
# 0   1   5      1      0.1
# 1   2   3      1      0.1
# 2   3   6      0      0.1
# 3   4   8      1      0.1
# 4   5   1      0      0.1
# 5   6   9      1      0.1
# 6   6   5      0      0.1
# 7   7   8      1      0.1
# 8   9   9      0      0.1
# 9   9   2      0      0.1

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt1=DecisionTreeClassifier(max_depth=1)

# %%
X=df.iloc[:,0:2].values
y=df.iloc[:,2].values

# %%
dt1.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
from sklearn.tree import plot_tree
plot_tree(dt1)
# Out:
# [Text(0.5, 0.75, 'x[1] <= 2.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.625, 0.5, '  False')]

# %%
plot_decision_regions(X,y,clf=dt1,legend=2)
# Out:
# <Axes: >

# %%
df['y_pred']=dt1.predict(X)

# %%
df
# Out:
#    X1  X2  label  weights  y_pred
# 0   1   5      1      0.1       1
# 1   2   3      1      0.1       1
# 2   3   6      0      0.1       1
# 3   4   8      1      0.1       1
# 4   5   1      0      0.1       0
# 5   6   9      1      0.1       1
# 6   6   5      0      0.1       1
# 7   7   8      1      0.1       1
# 8   9   9      0      0.1       1
# 9   9   2      0      0.1       0

# %%
def calculate_model_weight(error):
    return 0.5*np.log((1-error)/(error))

# %%
alpha1=calculate_model_weight(0.3)
alpha1
# Out:
# np.float64(0.42364893019360184)

# %%
def update_row_weight(row,alpha=0.423):
    if row['label']== row['y_pred']:
        return row['weights']*np.exp(-alpha)
    else:
        return row['weights']*np.exp(alpha)

# %%
df['update_weights']=df.apply(update_row_weight,axis=1)

# %%
df
# Out:
#    X1  X2  label  weights  y_pred  update_weights
# 0   1   5      1      0.1       1        0.065508
# 1   2   3      1      0.1       1        0.065508
# 2   3   6      0      0.1       1        0.152653
# 3   4   8      1      0.1       1        0.065508
# 4   5   1      0      0.1       0        0.065508
# 5   6   9      1      0.1       1        0.065508
# 6   6   5      0      0.1       1        0.152653
# 7   7   8      1      0.1       1        0.065508
# 8   9   9      0      0.1       1        0.152653
# 9   9   2      0      0.1       0        0.065508

# %%
df['normalized']=df['update_weights']/df['update_weights'].sum()

# %%
df
# Out:
#    X1  X2  label  weights  y_pred  update_weights  normalized
# 0   1   5      1      0.1       1        0.065508    0.071475
# 1   2   3      1      0.1       1        0.065508    0.071475
# 2   3   6      0      0.1       1        0.152653    0.166559
# 3   4   8      1      0.1       1        0.065508    0.071475
# 4   5   1      0      0.1       0        0.065508    0.071475
# 5   6   9      1      0.1       1        0.065508    0.071475
# 6   6   5      0      0.1       1        0.152653    0.166559
# 7   7   8      1      0.1       1        0.065508    0.071475
# 8   9   9      0      0.1       1        0.152653    0.166559
# 9   9   2      0      0.1       0        0.065508    0.071475

# %%
df['normalized'].sum()
# Out:
# np.float64(1.0)

# %%
df['upper']=np.cumsum(df['normalized'])

# %%
df['Lower']=df['upper']-df['normalized']

# %%
df[['X1','X2','label','weights','y_pred','update_weights','normalized','upper','Lower']]
# Out:
#    X1  X2  label  weights  y_pred  update_weights  normalized     upper  \
# 0   1   5      1      0.1       1        0.065508    0.071475  0.071475
# 1   2   3      1      0.1       1        0.065508    0.071475  0.142950
# 2   3   6      0      0.1       1        0.152653    0.166559  0.309508
# 3   4   8      1      0.1       1        0.065508    0.071475  0.380983
# 4   5   1      0      0.1       0        0.065508    0.071475  0.452458
# 5   6   9      1      0.1       1        0.065508    0.071475  0.523933
# 6   6   5      0      0.1       1        0.152653    0.166559  0.690492
# 7   7   8      1      0.1       1        0.065508    0.071475  0.761967
# 8   9   9      0      0.1       1        0.152653    0.166559  0.928525
# 9   9   2      0      0.1       0        0.065508    0.071475  1.000000
#
#       Lower
# 0  0.000000
# 1  0.071475
# 2  0.142950
# 3  0.309508
# 4  0.380983
# 5  0.452458
# 6  0.523933
# 7  0.690492
# 8  0.761967
# 9  0.928525

# %%
def create_new_dataset(df):
    indices=[]

    for i in range(df.shape[0]):
        a=np.random.random()
        for index,row in df.iterrows():
            if row['upper']>a and a>row['Lower']:
                indices.append(index)

    return indices

# %%
index_values=create_new_dataset(df)

# %%
index_values
# Out:
# [8, 0, 0, 1, 4, 4, 2, 1, 9, 4]

# %%
second_df=df.iloc[index_values,[0,1,2,3]]

# %%
second_df
# Out:
#    X1  X2  label  weights
# 8   9   9      0      0.1
# 0   1   5      1      0.1
# 0   1   5      1      0.1
# 1   2   3      1      0.1
# 4   5   1      0      0.1
# 4   5   1      0      0.1
# 2   3   6      0      0.1
# 1   2   3      1      0.1
# 9   9   2      0      0.1
# 4   5   1      0      0.1

# %%
dt2=DecisionTreeClassifier(max_depth=1)

# %%
X=df.iloc[:,0:2].values
y=df.iloc[:,2].values

# %%
dt2.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
from sklearn.tree import plot_tree
plot_tree(dt2)
# Out:
# [Text(0.5, 0.75, 'x[1] <= 2.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.625, 0.5, '  False')]
