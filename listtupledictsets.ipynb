# %%
print("Hello World")
# Out:
# Hello World

# %%
## LIST TUPLE SET AND DICTIONARY
# ordered and mutable collection of items and contain items of diffferent different data type.
#.insert to insert with the index where we want to insert and .remove to reove the first occurrence of the items
# pop the last element
# sort can also be done.
# reverse also a function
#.clear() remove all the items from the list
# slicing the list[::2] step size 

# enumerate to get the information about the index.
# for index,number in enumerate(numbers):
lst=[]
for x in range(10):
    lst.append(x**2)
print(lst)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
lst = [1, 2]
lst1 = lst[::-1]
print(lst1)
print(lst)  # Output: [2, 1]
# Out:
# [2, 1]
# [1, 2]

# %%
lst=[1,2,3,4,5]
n=2
rotated=lst[-n:]+lst[:-n]
print(lst)
print(rotated)
# Out:
# [1, 2, 3, 4, 5]
# [4, 5, 1, 2, 3]

# %%
list1 = [1, 2, 3]
list2 = [2, 3, 4]

intersection = list(set(list1) & set(list2))
print(intersection)  # Output: [2, 3]

# %%
## sets donot allow the duplicate elements.
# .remove remove the element if it is a member and .discard work as remove but not give the error if the element is not there.
# pop removes the first element.
# .clear clears all the elemts
set={1,2,3,4,5,6,7}
print(1 in set)
print(2 in set)
set1={1,2,3}
set2={2,3,4,5}
set1.intersection_update(set2)
# update the intesection element into the set 1
print(set1)
set1
# common element are just removed and the unoque elements are just combined.
#.issubset set 1 is subset of set 2
#.issuperset
# Out:
# True
# True
# {2, 3}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 19
#      17 text="My name is kirat and i learning about the sets"
#      18 word=text.split()
# ---> 19 unique_words=set(words)
#      20 print(unique_words)
#      21 print(len(unique_words))
#
# NameError: name 'words' is not defined

# %%
text="My name is kirat and i learning about the sets"
words=text.split()
unique_words=set(words)
print(unique_words)
print(len(unique_words))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 text="My name is kirat and i learning about the sets"
#       2 words=text.split()
# ----> 3 unique_words=set(words)
#       4 print(unique_words)
#       5 print(len(unique_words))
#
# TypeError: 'set' object is not callable

# %%
#Tuples in PYTHON
# ordered colection of items that are immutable.
empty_tuple=()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
lst=list()
print(type(lst))
# Out:
# <class 'list'>

# %%
  num=(1,2,3,4)
  print(num)
  num[1]="kirat"
  print(num)
  # for this change the tuple into the list then change the element into the list.
# Out:
# (1, 2, 3, 4)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 num=(1,2,3,4)
#       2 print(num)
# ----> 3 num[1]="kirat"
#       4 print(num)
#
# TypeError: 'tuple' object does not support item assignment

# %%
#.count,.index
numbers=(1,2,3,4,5,6)
numbers
print(numbers.count(1))
print(numbers.index(4))
## packing and unpacking tuple
packed_tuple=(1,'Kirat','Hello')
print(packed_tuple)
# Out:
# 1
# 3
# (1, 'Kirat', 'Hello')

# %%
a,b,c=packed_tuple
print(a)
print(b)
print(c)
# Out:
# 1
# Kirat
# Hello

# %%
#Unpacking with stars
numbers=(1,2,3,4,5,6)
first,*middle,last=numbers
print(first)
print(middle)
print(last)
#middle give the elemenst from teh 1 to the last-1
# Out:
# 1
# [2, 3, 4, 5]
# 6

# %%
## ***************************** DICTIONARIES *******************************
## same name value get replaced as not to create a key with the same name
## accesing the values using the get method()
## we can add update and delete the elements and the dictiobaries are the mutable elements.
## delete the key we used the del
## del[key]
#.keys to get the all the keys
#.values to get the all the alues
#.items to get the all the items

# %%
students={
    "student1":{"name":"kirat","age":32},
    "student2":{"name":"rahul","age":23}
} 
print(students)
# Out:
# {'student1': {'name': 'kirat', 'age': 32}, 'student2': {'name': 'rahul', 'age': 23}}

# %%
print(students["student2"]["name"])
# Out:
# rahul

# %%
students.items()
# Out:
# dict_items([('student1', {'name': 'kirat', 'age': 32}), ('student2', {'name': 'rahul', 'age': 23})])

# %%
for student_id,student_info in students.items():
    print(f"{student_id}:{student_info}")
    for key,value in student_info.items():
        print(f"{key}:{value}")
# Out:
# student1:{'name': 'kirat', 'age': 32}
# name:kirat
# age:32
# student2:{'name': 'rahul', 'age': 23}
# name:rahul
# age:23

# %%
numbers={1,2,2,3,3,3,4,4,4,4}
frequency={}

for number in numbers:
    if number in frequency:
        frequency[number]+=1
    else:
        frequency[number]=1
print(frequency)
# Out:
# {1: 1, 2: 1, 3: 1, 4: 1}

# %%
## merge two dictionaries
dict1={"a":1,"b":2}
dict2={"b":3,"c":4}
merge_dict={**dict1,**dict2}
print(merge_dict)
# Out:
# {'a': 1, 'b': 3, 'c': 4}

# %%
text = "kirat learning python"

char_count = {}  # empty dictionary

for char in text:
    if char in char_count:
        char_count[char] += 1
    else:
        char_count[char] = 1

# Print the dictionary
print("Character counts:")
for key in char_count:
    print(f"'{key}': {char_count[key]}")
# Out:
# Character counts:
# 'k': 1
# 'i': 2
# 'r': 2
# 'a': 2
# 't': 2
# ' ': 2
# 'l': 1
# 'e': 1
# 'n': 3
# 'g': 1
# 'p': 1
# 'y': 1
# 'h': 1
# 'o': 1

# %%
to_do_list=["Buy Groceries","Clean the house","Pay the Bills"]
to_do_list.append("Schedule the Meetings")
to_do_list.append("Go for Fun")
to_do_list.remove("Clean the house")

if "Pay the Bills" in to_do_list:
    print(" don't forget to pay the utlity Bills")
print("to_do_list Remaining")
for task in to_do_list:
    print(f"{task}")
# Out:
#  don't forget to pay the utlity Bills
# to_do_list Remaining
# Buy Groceries
# Pay the Bills
# Schedule the Meetings
# Go for Fun

# %%
feedback=["Great Service","Very Satisfied","Could be Better","Excellent Experience"]
feedback.append("Not happy with the Services")
positive_feedback_count=sum(1 for comment in feedback if "great"in comment.lower() or"excellent" in comment.lower())
print(f"Positive Feedback is:{positive_feedback_count}")

print("User_services")
for comment in feedback:
    print(f"-{comment}")
# Out:
# Positive Feedback is:2
# User_services
# -Great Service
# -Very Satisfied
# -Could be Better
# -Excellent Experience
# -Not happy with the Services
