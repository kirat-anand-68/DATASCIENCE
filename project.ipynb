# %%
import pandas as pd

# %%
df=pd.read_csv("student_habits_performance.csv")

# %%
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
# 2         Poor                   1              High School             Poor
# 3         Poor                   4                   Master             Good
# 4         Fair                   3                   Master             Good
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0
# 2                     1                            No        34.3
# 3                     1                           Yes        26.8
# 4                     1                            No        66.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
#  12  internet_quality               1000 non-null   object
#  13  mental_health_rating           1000 non-null   int64
#  14  extracurricular_participation  1000 non-null   object
#  15  exam_score                     1000 non-null   float64
# dtypes: float64(6), int64(3), object(7)
# memory usage: 125.1+ KB

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.head(2)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.isna().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
df=df.dropna()

# %%
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0              1.1            No                   85.0          8.0
# 1              2.3            No                   97.3          4.6
# 2              1.3            No                   94.8          8.0
# 3              1.0            No                   71.0          9.2
# 4              0.5            No                   90.9          4.9
# ..             ...           ...                    ...          ...
# 995            1.6            No                   77.0          7.5
# 996            2.4           Yes                   86.0          6.8
# 997            1.3            No                   61.9          6.5
# 998            1.1           Yes                  100.0          7.6
# 999            1.9            No                   89.4          7.1
#
#     diet_quality  exercise_frequency parental_education_level  \
# 0           Fair                   6                   Master
# 1           Good                   6              High School
# 2           Poor                   1              High School
# 3           Poor                   4                   Master
# 4           Fair                   3                   Master
# ..           ...                 ...                      ...
# 995         Fair                   2              High School
# 996         Poor                   1              High School
# 997         Good                   5                 Bachelor
# 998         Fair                   0                 Bachelor
# 999         Good                   2                 Bachelor
#
#     internet_quality  mental_health_rating extracurricular_participation  \
# 0            Average                     8                           Yes
# 1            Average                     8                            No
# 2               Poor                     1                            No
# 3               Good                     1                           Yes
# 4               Good                     1                            No
# ..               ...                   ...                           ...
# 995             Good                     6                           Yes
# 996          Average                     6                           Yes
# 997             Good                     9                           Yes
# 998          Average                     1                            No
# 999          Average                     8                            No
#
#      exam_score
# 0          56.2
# 1         100.0
# 2          34.3
# 3          26.8
# 4          66.4
# ..          ...
# 995        76.1
# 996        65.9
# 997        64.4
# 998        69.7
# 999        74.9
#
# [909 rows x 16 columns]

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 909, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df.describe()
# Out:
#               age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  909.000000           909.000000          909.000000     909.000000
# mean    20.475248             3.538724            2.504620       1.830363
# std      2.302721             1.469730            1.164802       1.071251
# min     17.000000             0.000000            0.000000       0.000000
# 25%     18.000000             2.500000            1.700000       1.000000
# 50%     20.000000             3.500000            2.500000       1.800000
# 75%     22.000000             4.500000            3.300000       2.600000
# max     24.000000             8.300000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count             909.000000   909.000000          909.000000
# mean               83.880308     6.474037            3.051705
# std                 9.453622     1.218943            2.035632
# min                56.000000     3.200000            0.000000
# 25%                77.500000     5.600000            1.000000
# 50%                84.200000     6.500000            3.000000
# 75%                90.700000     7.300000            5.000000
# max               100.000000    10.000000            6.000000
#
#        mental_health_rating  exam_score
# count            909.000000  909.000000
# mean               5.466447   69.558196
# std                2.857525   16.929436
# min                1.000000   18.400000
# 25%                3.000000   58.400000
# 50%                5.000000   70.400000
# 75%                8.000000   81.300000
# max               10.000000  100.000000

# %%
df.describe(include="object")
# Out:
#        student_id gender part_time_job diet_quality parental_education_level  \
# count         909    909           909          909                      909
# unique        909      3             2            3                        3
# top         S1999   Male            No         Fair              High School
# freq            1    440           713          396                      392
#
#        internet_quality extracurricular_participation
# count               909                           909
# unique                3                             2
# top                Good                            No
# freq                410                           620

# %%
categorical_cols=["gender","part_time_job","diet_quality","parental_education_level","internet_quality","extracurricular_participation"]

# %%
for col in categorical_cols:
    print(f"value counts for {col}:\n {df[col].value_counts()}")
# Out:
# value counts for gender:
#  gender
# Male      440
# Female    433
# Other      36
# Name: count, dtype: int64
# value counts for part_time_job:
#  part_time_job
# No     713
# Yes    196
# Name: count, dtype: int64
# value counts for diet_quality:
#  diet_quality
# Fair    396
# Good    347
# Poor    166
# Name: count, dtype: int64
# value counts for parental_education_level:
#  parental_education_level
# High School    392
# Bachelor       350
# Master         167
# Name: count, dtype: int64
# value counts for internet_quality:
#  internet_quality
# Good       410
# Average    352
# Poor       147
# Name: count, dtype: int64
# value counts for extracurricular_participation:
#  extracurricular_participation
# No     620
# Yes    289
# Name: count, dtype: int64

# %%
df.hist(bins=20,edgecolor="black")
plt.tight_layout()
plt.show()

# %%
for col in categorical_cols:
    sns.countplot(data=df,x= col)
    plt.title(f"Distribution of {col}")
    plt.xticks(rotation=45)
    plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                             age  study_hours_per_day  social_media_hours  \
# age                    1.000000             0.007150           -0.023854
# study_hours_per_day    0.007150             1.000000            0.007364
# social_media_hours    -0.023854             0.007364            1.000000
# netflix_hours          0.005841            -0.014493            0.011865
# attendance_percentage -0.030203             0.028967            0.049356
# sleep_hours            0.040498            -0.026241            0.026861
# exercise_frequency    -0.005718            -0.024708           -0.023975
# mental_health_rating  -0.052137            -0.015896           -0.000417
# exam_score            -0.012833             0.822950           -0.171672
#
#                        netflix_hours  attendance_percentage  sleep_hours  \
# age                         0.005841              -0.030203     0.040498
# study_hours_per_day        -0.014493               0.028967    -0.026241
# social_media_hours          0.011865               0.049356     0.026861
# netflix_hours               1.000000              -0.015008    -0.017006
# attendance_percentage      -0.015008               1.000000     0.001972
# sleep_hours                -0.017006               0.001972     1.000000
# exercise_frequency         -0.004155              -0.010563     0.030013
# mental_health_rating       -0.016612              -0.017096    -0.010653
# exam_score                 -0.166578               0.096005     0.122294
#
#                        exercise_frequency  mental_health_rating  exam_score
# age                             -0.005718             -0.052137   -0.012833
# study_hours_per_day             -0.024708             -0.015896    0.822950
# social_media_hours              -0.023975             -0.000417   -0.171672
# netflix_hours                   -0.004155             -0.016612   -0.166578
# attendance_percentage           -0.010563             -0.017096    0.096005
# sleep_hours                      0.030013             -0.010653    0.122294
# exercise_frequency               1.000000             -0.001500    0.161397
# mental_health_rating            -0.001500              1.000000    0.317945
# exam_score                       0.161397              0.317945    1.000000

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap="coolwarm" ,fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
df.describe().columns
# Out:
# Index(['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
#        'attendance_percentage', 'sleep_hours', 'exercise_frequency',
#        'mental_health_rating', 'exam_score'],
#       dtype='object')

# %%
numeric_features=['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
       'attendance_percentage', 'sleep_hours', 'exercise_frequency',
       'mental_health_rating']

# %%
for feature in numeric_features:
    sns.scatterplot(data=df,x=feature,y="exam_score")
    plt.title(f"{feature} vs Exam Score")
    plt.show()

# %%
for col in categorical_cols:
    sns.boxplot(data=df,x=col,y="exam_score")
    plt.title(f"Exam Score by {col}")
    plt.xticks(rotation=45)
    plt.show()

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.linear_model import LinearRegression,ridge_regression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
# 2         Poor                   1              High School             Poor
# 3         Poor                   4                   Master             Good
# 4         Fair                   3                   Master             Good
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0
# 2                     1                            No        34.3
# 3                     1                           Yes        26.8
# 4                     1                            No        66.4

# %%
features=['study_hours_per_day','attendance_percentage','mental_health_rating','sleep_hours','part_time_job']

# %%
target="exam_score"

# %%
df_model=df[features + [target]].copy()

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                    0.0                   85.0                     8
# 1                    6.9                   97.3                     8
# 2                    1.4                   94.8                     1
# 3                    1.0                   71.0                     1
# 4                    5.0                   90.9                     1
# ..                   ...                    ...                   ...
# 995                  2.6                   77.0                     6
# 996                  2.9                   86.0                     6
# 997                  3.0                   61.9                     9
# 998                  5.4                  100.0                     1
# 999                  4.3                   89.4                     8
#
#      sleep_hours part_time_job  exam_score
# 0            8.0            No        56.2
# 1            4.6            No       100.0
# 2            8.0            No        34.3
# 3            9.2            No        26.8
# 4            4.9            No        66.4
# ..           ...           ...         ...
# 995          7.5            No        76.1
# 996          6.8           Yes        65.9
# 997          6.5            No        64.4
# 998          7.6           Yes        69.7
# 999          7.1            No        74.9
#
# [909 rows x 6 columns]

# %%
le=LabelEncoder()

# %%
df_model["part_time_job"]=le.fit_transform(df_model['part_time_job'])

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  mental_health_rating  \
# 0                    0.0                   85.0                     8
# 1                    6.9                   97.3                     8
# 2                    1.4                   94.8                     1
# 3                    1.0                   71.0                     1
# 4                    5.0                   90.9                     1
# ..                   ...                    ...                   ...
# 995                  2.6                   77.0                     6
# 996                  2.9                   86.0                     6
# 997                  3.0                   61.9                     9
# 998                  5.4                  100.0                     1
# 999                  4.3                   89.4                     8
#
#      sleep_hours  part_time_job  exam_score
# 0            8.0              0        56.2
# 1            4.6              0       100.0
# 2            8.0              0        34.3
# 3            9.2              0        26.8
# 4            4.9              0        66.4
# ..           ...            ...         ...
# 995          7.5              0        76.1
# 996          6.8              1        65.9
# 997          6.5              0        64.4
# 998          7.6              1        69.7
# 999          7.1              0        74.9
#
# [909 rows x 6 columns]

# %%
X=df_model[features]

# %%
y=df_model[target]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
len(y_test)
# Out:
# 182

# %%
models={
    "LinearRegression":{
        "model": LinearRegression(),
        "params":{}
    },
    "DecisionTree":{
        "model": DecisionTreeRegressor(),
        "params":{"max_depth":[3,5,10],"min_samples_split":[2,5]}

    },
    "RandomForest":{
        "model":RandomForestRegressor(),
        "params":{"n_estimators":[50,100],"max_depth":[5,10]}
    }
}

# %%
best_models=[]

# %%
# ✅ Loop through models
for name, config in models.items():
    print(f"Training {name}")

    grid = GridSearchCV(
        estimator=config["model"],
        param_grid=config["params"],
        cv=5,
        scoring="neg_mean_squared_error"
    )

    grid.fit(X_train, y_train)

    y_pred = grid.predict(X_test)

    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)

    best_models.append({
        "model": name,
        "best_params": grid.best_params_,
        "rmse": rmse,
        "r2": r2
    })
# Out:
# Training LinearRegression
# Training DecisionTree
# Training RandomForest

# %%
best_models
# Out:
# [{'model': 'LinearRegression', 'best_params': {}, 'r2': 0.8031231548615336},
#  {'model': 'LinearRegression', 'best_params': {}, 'r2': 0.8031231548615336},
#  {'model': 'LinearRegression',
#   'best_params': {},
#   'rmse': np.float64(7.168487874156787),
#   'r2': 0.8031231548615336},
#  {'model': 'LinearRegression',
#   'best_params': {},
#   'rmse': np.float64(7.168487874156787),
#   'r2': 0.8031231548615336},
#  {'model': 'LinearRegression',
#   'best_params': {},
#   'rmse': np.float64(7.168487874156787),
#   'r2': 0.8031231548615336},
#  {'model': 'LinearRegression',
#   'best_params': {},
#   'rmse': np.float64(7.168487874156787),
#   'r2': 0.8031231548615336},
#  {'model': 'DecisionTree',
#   'best_params': {'max_depth': 5, 'min_samples_split': 2},
#   'rmse': np.float64(8.225203375897355),
#   'r2': 0.7408012984144969},
#  {'model': 'RandomForest',
#   'best_params': {'max_depth': 5, 'n_estimators': 100},
#   'rmse': np.float64(7.489509678316654),
#   'r2': 0.7850951067875425},
#  {'model': 'LinearRegression',
#   'best_params': {},
#   'rmse': np.float64(7.168487874156787),
#   'r2': 0.8031231548615336},
#  {'model': 'DecisionTree',
#   'best_params': {'max_depth': 5, 'min_samples_split': 2},
#   'rmse': np.float64(8.267183285495253),
#   'r2': 0.7381487425528956},
#  {'model': 'RandomForest',
#   'best_params': {'max_depth': 5, 'n_estimators': 100},
#   'rmse': np.float64(7.419833952270879),
#   'r2': 0.789075074591725}]

# %%
results_df=pd.DataFrame(best_models)

# %%
results_df.sort_values(by="rmse")
# Out:
#                model                               best_params        r2  \
# 2   LinearRegression                                        {}  0.803123
# 3   LinearRegression                                        {}  0.803123
# 4   LinearRegression                                        {}  0.803123
# 5   LinearRegression                                        {}  0.803123
# 8   LinearRegression                                        {}  0.803123
# 10      RandomForest     {'max_depth': 5, 'n_estimators': 100}  0.789075
# 7       RandomForest     {'max_depth': 5, 'n_estimators': 100}  0.785095
# 6       DecisionTree  {'max_depth': 5, 'min_samples_split': 2}  0.740801
# 9       DecisionTree  {'max_depth': 5, 'min_samples_split': 2}  0.738149
# 0   LinearRegression                                        {}  0.803123
# 1   LinearRegression                                        {}  0.803123
#
#         rmse
# 2   7.168488
# 3   7.168488
# 4   7.168488
# 5   7.168488
# 8   7.168488
# 10  7.419834
# 7   7.489510
# 6   8.225203
# 9   8.267183
# 0        NaN
# 1        NaN

# %%
import joblib

best_row=results_df.sort_values(by="rmse").iloc[0]

# %%
best_row
# Out:
# model          LinearRegression
# best_params                  {}
# r2                     0.803123
# rmse                   7.168488
# Name: 2, dtype: object

# %%
best_model_name=best_row["model"]

# %%
best_model_name
# Out:
# 'LinearRegression'

# %%
best_model_config=models[best_model_name]

# %%
best_model_config
# Out:
# {'model': LinearRegression(), 'params': {}}

# %%
final_model=best_model_config["model"]

# %%
final_model.fit(X,y)
# Out:
# LinearRegression()

# %%
final_model.predict(X_test)
# Out:
# array([ 65.92873416,  59.80546684,  71.74445088,  80.12262938,
#         85.31749649,  70.52672235,  82.25691263,  70.22148331,
#         73.20131605,  55.22074637,  63.00446683,  51.25205314,
#         76.48969124,  79.7245903 ,  69.31005922,  78.4898864 ,
#         71.11753121,  84.62669148,  71.9069882 ,  53.7393235 ,
#         57.43241342,  40.22731221,  76.75958523,  69.65327425,
#         77.28506823,  74.89289694,  74.66430702,  71.80449683,
#         68.22890505,  66.33382306,  65.33003352,  55.7323605 ,
#         67.06989821,  76.23992153,  75.00352966,  90.63779187,
#         63.21769009,  66.71216009,  37.70865932,  72.17523691,
#         54.28921371,  58.35889122,  63.3153885 ,  85.31042026,
#         51.45722985,  67.04794846,  56.51857377,  94.48143692,
#         79.58150708,  51.04420646,  60.78719557,  66.2175741 ,
#         62.717919  ,  57.8430186 ,  60.37009385, 105.01596237,
#         56.84795774,  57.59364973,  57.45957817,  93.5987542 ,
#         74.8589124 ,  72.71447601,  54.69003354, 100.00884675,
#         76.9384696 ,  54.20184513,  66.42722397,  94.4572444 ,
#         50.38351248,  82.2417553 ,  69.37146115,  76.36598796,
#         72.64278476,  45.70477712,  78.07562614,  92.69074923,
#         66.22583241,  61.7913346 ,  48.67665262,  87.18702105,
#         71.00132175,  73.50744843,  54.77872093,  82.57292072,
#         73.87388264,  87.78875123,  57.67033365,  68.33827278,
#         77.60448884,  74.53698275,  75.5095826 ,  66.42058582,
#         79.30877704,  70.61496485,  52.00021266,  55.74098408,
#         45.83696497,  86.30137744,  72.25779551,  91.54818993,
#         97.95605523,  65.81297953,  56.21699206,  86.04857975,
#         86.04159457,  75.52807025,  53.62059091, 102.67076152,
#         84.17072978,  55.66431716,  56.76860088,  66.5155005 ,
#         70.06256803,  89.8219083 ,  76.53481528,  44.87641598,
#         79.98469099,  80.45227491,  73.76225891,  70.21478147,
#         97.04729563,  57.8301418 ,  63.08783432,  67.1142276 ,
#         77.67278715,  66.70036983,  59.38276315,  53.98710733,
#         50.09576014,  37.08526345,  38.72620623,  64.69940863,
#         84.1404169 ,  56.00371918,  93.9348698 ,  48.21064224,
#         65.13307337,  85.9407813 ,  68.93258247,  63.02878767,
#         53.93516025,  68.26348682,  71.62634586,  75.71664301,
#         67.09112318,  44.07954472,  83.76282292,  32.78247569,
#         85.07548216,  70.58020241,  36.59323364,  67.37855373,
#         72.00500419,  53.07774872,  74.55553431,  62.33964812,
#         61.28183191,  88.10129326,  77.76963809,  72.24230521,
#         56.9504718 ,  68.8414418 ,  40.0082463 ,  53.80314099,
#         55.18712999,  68.8899433 ,  79.77697389,  63.24170396,
#         81.11499936,  48.07116615,  62.76704043,  50.42847388,
